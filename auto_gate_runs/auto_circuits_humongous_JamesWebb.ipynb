# %% [markdown]
# <a href="https://colab.research.google.com/github/pinballsurgeon/deluxo_adjacency/blob/main/auto_gate_runs/auto_circuits_humongous_JamesWebb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Auto Quantum Circuits
# #### dehls - pinballsurgeon@gmail.com

# %% [markdown]
# ###Installs

# %%
# tensorflow quantum
# !pip install --quiet tensorflow_quantum

# bloch sphere
# !pip install --quiet qutip

# gdown drive for dans datasets
# !pip install --upgrade --no-cache-dir gdown
# Out:
#      |████████████████████████████████| 10.5 MB 3.8 MB/s
#      |████████████████████████████████| 90 kB 7.0 MB/s
#      |████████████████████████████████| 90 kB 6.1 MB/s
#      |████████████████████████████████| 100 kB 7.5 MB/s
#      |████████████████████████████████| 6.1 MB 12.0 MB/s
#      |████████████████████████████████| 1.6 MB 31.6 MB/s
#      |████████████████████████████████| 576 kB 41.8 MB/s
#      |████████████████████████████████| 46 kB 1.6 MB/s
#      |████████████████████████████████| 641 kB 16.0 MB/s
#      |████████████████████████████████| 541 kB 44.5 MB/s
#      |████████████████████████████████| 541 kB 36.4 MB/s
#      |████████████████████████████████| 437 kB 46.1 MB/s
#      |████████████████████████████████| 93 kB 1.3 MB/s
#      |████████████████████████████████| 93 kB 593 kB/s
#      |████████████████████████████████| 93 kB 920 kB/s
#      |████████████████████████████████| 93 kB 825 kB/s
#      |████████████████████████████████| 93 kB 836 kB/s
#      |████████████████████████████████| 93 kB 1.1 MB/s
#      |████████████████████████████████| 93 kB 979 kB/s
#      |████████████████████████████████| 93 kB 1.3 MB/s
#      |████████████████████████████████| 93 kB 928 kB/s
#      |████████████████████████████████| 92 kB 931 kB/s
#      |████████████████████████████████| 93 kB 701 kB/s
#      |████████████████████████████████| 93 kB 1.1 MB/s
#      |████████████████████████████████| 93 kB 642 kB/s
#      |████████████████████████████████| 92 kB 762 kB/s
#      |████████████████████████████████| 92 kB 482 kB/s
#      |████████████████████████████████| 92 kB 137 kB/s
#      |████████████████████████████████| 92 kB 143 kB/s
#      |████████████████████████████████| 92 kB 9.1 MB/s
#      |████████████████████████████████| 91 kB 7.7 MB/s
#      |████████████████████████████████| 91 kB 8.4 MB/s
#      |████████████████████████████████| 91 kB 6.6 MB/s
#      |████████████████████████████████| 91 kB 4.2 MB/s
#      |████████████████████████████████| 91 kB 7.9 MB/s
#      |████████████████████████████████| 91 kB 8.2 MB/s
#      |████████████████████████████████| 91 kB 6.0 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydata-google-auth 1.4.0 requires google-auth<3.0dev,>=1.25.0; python_version >= "3.6", but you have google-auth 1.18.0 which is incompatible.
# google-cloud-bigquery-storage 1.1.2 requires google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5, but you have google-api-core 1.21.0 which is incompatible.
#      |████████████████████████████████| 14.7 MB 5.2 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14951 sha256=9efb9ae9c045a33a02b2cd4b06d04e82b086ecfff82c952f90618821ef65ad8e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i18rnc5e/wheels/3d/ec/b0/a96d1d126183f98570a785e6bf8789fca559853a9260e928e1
# Successfully built gdown
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.5.1

# %% [markdown]
# ###Imports

# %%
### standard dan-dards
import cirq
import sympy
import tensorflow
import numpy
import gc
import random
import gdown
import shutil
import os
from os import listdir
import cv2
from tensorflow.keras.utils import img_to_array
import pandas


# metric plotting
# %matplotlib inline
from matplotlib import pyplot
from matplotlib.pyplot import figure

# tf quantum
import tensorflow_quantum

# circuit/operations visualizers
import qutip
from cirq.contrib.svg import SVGCircuit

# %% [markdown]
# ###Experiment configuration and hyper-parameters

# %%
### Define your quantum machine learning experiment, the values here are optimized for best 'Colab free-tier' experience

# which dataset do you want to predict against?
# 1 = James Webb vs. Hubble sample classification
# 2 = Gram positive vs negative bacteria classification
# 3 = Wild fire from space classification
# 10 = MNIST written numerical classification
dataset_select = 1


# qubit grid sizes - how big do you want your circuit's grid size range to be
experiment_grid_sizes = [2, 4]

# experiment count - how many arrangements of gates, per qubit grid, to run
experiment_runs = 5

# gate combination range - how many, or few, combination of gates per experiemental run
min_gate_cobination = 1
max_gate_cobination = 4


# cirq gates to hyperparameterize
gate_mix = [cirq.CZ
           ,cirq.CNOT
           ,cirq.XX
           ,cirq.ISWAP
           ,cirq.ZZ
           ,cirq.SWAP
           ,cirq.YY
           ,cirq.CX]


# learning parameters
EPOCHS = 50
BATCH_SIZE = 5
ADAM_OPTIMIZER_LEARNING_RATE = 0.00011

# for MINST binary classifier, pick a single digit for TARGET and a single digit for JUNK
target_mnist_digit = 3
junk_mnist_digit = 4

# %% [markdown]
# ###Helper Functions

# %%
### Initialize circuit - given a data and out qubit structure, build dynamic circuit
class circuit_struct():
    def __init__(self, data_qubits, readout):
        self.data_qubits = data_qubits
        self.readout = readout
    
    def add_layer(self, circuit, gate, prefix):
        for i, qubit in enumerate(self.data_qubits):
            symbol = sympy.Symbol(prefix + '-' + str(i))
            circuit.append(gate(qubit, self.readout)**symbol)

# %%
### Populate circuit with gates - given a combination of qubit grid size and gate population, build 
def create_quantum_model(gridSize, hyperGates):

    # cirq
    data_qubits = cirq.GridQubit.rect(gridSize, gridSize)
    readout = cirq.GridQubit(-1, -1)         
    circuit = cirq.Circuit()
    
    # prepare the readout qubit
    circuit.append(cirq.X(readout))
    circuit.append(cirq.H(readout))
    
    # create qubit
    builder = circuit_struct(
        data_qubits = data_qubits,
        readout=readout)

    # buid layers
    for gate in hyperGates:

      # add specified gate and name
      builder.add_layer(circuit, gate, str(gate))
   
    # prepare the readout qubit
    circuit.append(cirq.H(readout))

    return circuit, cirq.Z(readout)

# %%
### image pixels to qubit
def convert_to_circuit(image):

    # flatten array
    values = numpy.ndarray.flatten(image)
    
    # establish 4x4 circuit
    qubits = cirq.GridQubit.rect(4, 4)
    circuit = cirq.Circuit()

    # 
    for i, value in enumerate(values):
        if value:
            circuit.append(cirq.X(qubits[i]))
    return circuit

# %%
### this example is for binary classification, so only keep one MNIST class/digit as target, and then one other as NON-TARGET/JUNK
def binary_filter(x, y):

    # identify rows that will be kept
    keep = (y == target_mnist_digit) | (y == junk_mnist_digit)
    
    # remove excess
    x, y = x[keep], y[keep]

    # establish target 1/0
    y = y == target_mnist_digit
 
    return x,y

# %%
### reveal experiment results per run
def experiment_reveal(log, run):

  fig, (ax1, ax2) = pyplot.subplots(2)
  pyplot.title('MSE Loss and Accuracy of %s gated Parametrized Quantum Circuit' % (log[run]['gates']), fontdict = {'fontsize' :16})

  ax1.plot(log[run]['history'].history['loss'])
  ax1.plot(log[run]['history'].history['val_loss'])
  ax1.set_ylabel('MAPL')

  ax2.plot(log[run]['history'].history['mean_squared_error'])
  ax2.plot(log[run]['history'].history['val_mean_squared_error'] )
  ax2.set_ylabel('MSE')
  ax2.set_xlabel('Epochs')
  
  fig = pyplot.gcf()
  fig.set_size_inches(12.5, 7.5)

  return log[run]['circuit']

# %%
### import dan ehlers' novel supplied datasource
def dans_data(url, path):

  # if directory exists, delete as to make room
  if os.path.isdir(path):
    shutil.rmtree(path, ignore_errors=True)

  # download from dan's drive, yay security exposure
  gdown.download_folder(url, quiet=True)

  return path

# %% [markdown]
# ###Build experiment circuits and gates

# %%
### build experiment

experiment_design = []

# given experiement design parameters, build experiment(s)
for run in range(1, experiment_runs+1):

  # gate combination
  gate_combination = random.choices(gate_mix, k=random.randrange(min_gate_cobination, max_gate_cobination+1))

  # print random experiment gate participants
  print('Experiment %d Gates:' % run); print(gate_combination); print('')

  # build experiment
  experiment_design.append(gate_combination)
# Out:
# Experiment 1 Gates:
# [cirq.XX]
#
# Experiment 2 Gates:
# [cirq.ISWAP]
#
# Experiment 3 Gates:
# [cirq.SWAP, cirq.CNOT, cirq.CNOT]
#
# Experiment 4 Gates:
# [cirq.SWAP, cirq.ZZ, cirq.CZ, cirq.SWAP]
#
# Experiment 5 Gates:
# [cirq.YY, cirq.XX, cirq.CNOT]

# %% [markdown]
# ###Load Dataset(s)

# %%
### download data source as specified, manage datasource specific handlers here

# download drive share, per datasource selection
if dataset_select == 1:              # james webb vs. hubble telescope classification
  paths = dans_data("https://drive.google.com/drive/folders/1Ae4sZyMvJ02ht5O6UEBCpWg2R1e_Ihr3?usp=sharing",'/content/tele_source')
  trg_label_prefix = 'jw_'

elif dataset_select == 2:            # bacteria gram positive vs negative classification
  paths = dans_data("https://drive.google.com/drive/folders/1hhx1mEfWz-ThviwOqXK63v3wy2J7xV2c?usp=sharing",'/content/bact_source')
  trg_label_prefix = 'pos_'

elif dataset_select == 3:            # wild fire classification
  paths = dans_data("https://drive.google.com/drive/folders/1KRKEq8ZH7aKIVDRZQjknpEza2TnhiRxw?usp=sharing",'/content/fire_source')
  trg_label_prefix = 'pos_'

# %%
### ingest and process dehls created datasets
imagePaths = [paths +'/' + f for f in listdir(paths)]
data = []
labels = []

imagePaths = sorted(list(imagePaths))
print(imagePaths)

# loop over the input images
for imagePath in imagePaths:
    # load the image, pre-process it, and store it in the data list
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.resize(image, (28, 28))
    image = img_to_array(image)
    data.append(image)

    if trg_label_prefix in imagePath:
      labels.append(1)
    else:
      labels.append(0)

data = numpy.array(data, dtype="float") / 255.0
# Out:
# ['/content/tele_source/hb_1.bmp', '/content/tele_source/hb_10.bmp', '/content/tele_source/hb_11.bmp', '/content/tele_source/hb_12.bmp', '/content/tele_source/hb_13.bmp', '/content/tele_source/hb_14.bmp', '/content/tele_source/hb_15.bmp', '/content/tele_source/hb_16.bmp', '/content/tele_source/hb_17.bmp', '/content/tele_source/hb_18.bmp', '/content/tele_source/hb_19.bmp', '/content/tele_source/hb_2.bmp', '/content/tele_source/hb_20.bmp', '/content/tele_source/hb_3.bmp', '/content/tele_source/hb_4.bmp', '/content/tele_source/hb_5.bmp', '/content/tele_source/hb_6.bmp', '/content/tele_source/hb_7.bmp', '/content/tele_source/hb_8.bmp', '/content/tele_source/hb_9.bmp', '/content/tele_source/jw_1.bmp', '/content/tele_source/jw_10.bmp', '/content/tele_source/jw_11.bmp', '/content/tele_source/jw_12.bmp', '/content/tele_source/jw_13.bmp', '/content/tele_source/jw_14.bmp', '/content/tele_source/jw_15.bmp', '/content/tele_source/jw_16.bmp', '/content/tele_source/jw_17.bmp', '/content/tele_source/jw_18.bmp', '/content/tele_source/jw_19.bmp', '/content/tele_source/jw_2.bmp', '/content/tele_source/jw_20.bmp', '/content/tele_source/jw_3.bmp', '/content/tele_source/jw_4.bmp', '/content/tele_source/jw_5.bmp', '/content/tele_source/jw_6.bmp', '/content/tele_source/jw_7.bmp', '/content/tele_source/jw_8.bmp', '/content/tele_source/jw_9.bmp']

# %%
### establish dataset, here the MNIST numerical yada-yada

# 1. import mnist digits
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.mnist.load_data()

# 2. rescale images to [0 - 1]
x_train, x_test = x_train[..., numpy.newaxis]/255.0, x_test[..., numpy.newaxis]/255.0

# 3. quantum experiment is binary classification, so only keep two classes/digit examples
x_train, y_train = binary_filter(x_train, y_train)
x_test, y_test = binary_filter(x_test, y_test)

# 4. change dataset from which to predict against, with MANUAL CONVOLUTIONS
if (dataset_select < 10):       # non MNIST sources
  x_train = data + [numpy.flip(x) for x in data] + [numpy.rot90(x) for x in data] + [numpy.fliplr(x) for x in data] + [numpy.flipud(x) for x in data]
  x_test = [numpy.rot90(x) for x in data]
  y_train = numpy.array(labels) + numpy.array(labels) + numpy.array(labels) + numpy.array(labels) + numpy.array(labels)

  y_test = numpy.array(labels)

# 5. resize image
x_train_small = tensorflow.image.resize(x_train, (4,4)).numpy()
x_test_small = tensorflow.image.resize(x_test, (4,4)).numpy()

# 6. convert circuit pixels/cells into individual qubits
x_train_circ = [convert_to_circuit(x) for x in x_train_small]
x_test_circ = [convert_to_circuit(x) for x in x_test_small]

# 7. convert to qubit imagery into tensors
x_train_tfcirc = tensorflow_quantum.convert_to_tensor(x_train_circ)
x_test_tfcirc = tensorflow_quantum.convert_to_tensor(x_test_circ)

# %% [markdown]
# ###Tensorflow quantum network

# %%
### tensorflow callbacks, here specifically garbage collection as to reduce memory load below colab free tier
class mem_release(tensorflow.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()

# %%
### tensorflow quantum experimental gate combinatorial iterator 

# keep track of experiment conditions and results
experiment_count = 0
experiment_log = {}


for gates in experiment_design:
  for gridSize_int in experiment_grid_sizes:


    # initialize quantum circuit
    model_circuit, model_readout = create_quantum_model(gridSize_int, gates)


    # build tf model
    model = tensorflow.keras.Sequential([
        
        # input data circuit as tf.string
        tensorflow.keras.layers.Input(shape=(), dtype=tensorflow.string),

        # parameterized quantum circuit
        tensorflow_quantum.layers.PQC(model_circuit, model_readout),])


    # compile model and determine loss / optimizer approach, for this introductory we'll focus on memory
    model.compile(

        # loss, mean square error
        # loss=tensorflow.keras.losses.binary_crossentropy,
        loss=tensorflow.keras.losses.mean_absolute_percentage_error,

        # optimizer, Adam with specifiable learning rate
        optimizer=tensorflow.keras.optimizers.Adam(learning_rate=ADAM_OPTIMIZER_LEARNING_RATE),
      
        # metrics, accuracy
        metrics=[tensorflow.keras.metrics.mean_absolute_percentage_error
               , tensorflow.keras.metrics.mean_absolute_error
               , tensorflow.keras.metrics.mean_squared_error
               ]
      )
    
    # display model parameters
    print(''); print(''.join(str(gates))); print(model.summary())

    # train model for experiment, define training and validation populations, callbacks ect.
    experiment_history = model.fit(
        x_train_tfcirc,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1,
        callbacks=[mem_release()
                  ,tensorflow.keras.callbacks.EarlyStopping(monitor='loss', patience=3)],
        validation_data=(x_test_tfcirc, y_test)
        )

    # after training, evaluate final model representation against test set
    experiment_results = model.evaluate(x_test_tfcirc, y_test)

    # record experiment
    experiment_count += 1
    experiment_log[experiment_count] = {'circuit' : model_circuit       
                                       ,'gates'   : gates
                                       ,'history' : experiment_history
                                       ,'results' : experiment_results }
# Out:
# [cirq.XX]
# Model: "sequential_66"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_66 (PQC)                (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 4s 385ms/step - loss: 500000256.0000 - mean_absolute_percentage_error: 500000256.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 500000320.0000 - val_mean_absolute_percentage_error: 500000320.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 2/50
# 8/8 [==============================] - 2s 305ms/step - loss: 500000352.0000 - mean_absolute_percentage_error: 500000320.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 500000096.0000 - val_mean_absolute_percentage_error: 500000096.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 3/50
# 8/8 [==============================] - 2s 312ms/step - loss: 500000256.0000 - mean_absolute_percentage_error: 500000256.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 500000320.0000 - val_mean_absolute_percentage_error: 500000320.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 4/50
# 8/8 [==============================] - 2s 316ms/step - loss: 500000320.0000 - mean_absolute_percentage_error: 500000320.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 500000320.0000 - val_mean_absolute_percentage_error: 500000320.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# 2/2 [==============================] - 1s 58ms/step - loss: 500000416.0000 - mean_absolute_percentage_error: 500000416.0000 - mean_absolute_error: 1.3000 - mean_squared_error: 2.1000
#
# [cirq.XX]
# Model: "sequential_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_67 (PQC)                (None, 1)                 16
#
# =================================================================
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 5s 532ms/step - loss: 499999936.0000 - mean_absolute_percentage_error: 499999936.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 499999904.0000 - val_mean_absolute_percentage_error: 499999904.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 2/50
# 8/8 [==============================] - 4s 498ms/step - loss: 499999936.0000 - mean_absolute_percentage_error: 499999936.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 499999840.0000 - val_mean_absolute_percentage_error: 499999840.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 3/50
# 8/8 [==============================] - 4s 498ms/step - loss: 499999936.0000 - mean_absolute_percentage_error: 499999936.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 499999936.0000 - val_mean_absolute_percentage_error: 499999936.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# Epoch 4/50
# 8/8 [==============================] - 4s 485ms/step - loss: 500000064.0000 - mean_absolute_percentage_error: 500000064.0000 - mean_absolute_error: 3.5000 - mean_squared_error: 18.5000 - val_loss: 499999936.0000 - val_mean_absolute_percentage_error: 499999936.0000 - val_mean_absolute_error: 1.5000 - val_mean_squared_error: 2.5000
# 2/2 [==============================] - 1s 88ms/step - loss: 500000064.0000 - mean_absolute_percentage_error: 500000064.0000 - mean_absolute_error: 1.5000 - mean_squared_error: 2.5000
#
# [cirq.ISWAP]
# Model: "sequential_68"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_68 (PQC)                (None, 1)                 4
#
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 4s 359ms/step - loss: 10015717.0000 - mean_absolute_percentage_error: 10015717.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4002 - val_loss: 9934287.0000 - val_mean_absolute_percentage_error: 9934287.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4805
# Epoch 2/50
# 8/8 [==============================] - 2s 317ms/step - loss: 9861187.0000 - mean_absolute_percentage_error: 9861187.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4017 - val_loss: 9777348.0000 - val_mean_absolute_percentage_error: 9777348.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4808
# Epoch 3/50
# 8/8 [==============================] - 3s 351ms/step - loss: 9701762.0000 - mean_absolute_percentage_error: 9701762.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4032 - val_loss: 9617794.0000 - val_mean_absolute_percentage_error: 9617794.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4811
# Epoch 4/50
# 8/8 [==============================] - 3s 412ms/step - loss: 9549950.0000 - mean_absolute_percentage_error: 9549950.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4049 - val_loss: 9454649.0000 - val_mean_absolute_percentage_error: 9454649.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4814
# Epoch 5/50
# 8/8 [==============================] - 2s 301ms/step - loss: 9384178.0000 - mean_absolute_percentage_error: 9384176.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4065 - val_loss: 9297039.0000 - val_mean_absolute_percentage_error: 9297039.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4818
# Epoch 6/50
# 8/8 [==============================] - 3s 368ms/step - loss: 9233684.0000 - mean_absolute_percentage_error: 9233684.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4081 - val_loss: 9137857.0000 - val_mean_absolute_percentage_error: 9137857.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4821
# Epoch 7/50
# 8/8 [==============================] - 3s 368ms/step - loss: 9073474.0000 - mean_absolute_percentage_error: 9073474.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4097 - val_loss: 8985664.0000 - val_mean_absolute_percentage_error: 8985664.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4824
# Epoch 8/50
# 8/8 [==============================] - 2s 310ms/step - loss: 8920173.0000 - mean_absolute_percentage_error: 8920173.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4111 - val_loss: 8835193.0000 - val_mean_absolute_percentage_error: 8835193.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4826
# Epoch 9/50
# 8/8 [==============================] - 2s 300ms/step - loss: 8763782.0000 - mean_absolute_percentage_error: 8763782.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4125 - val_loss: 8690226.0000 - val_mean_absolute_percentage_error: 8690226.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4829
# Epoch 10/50
# 8/8 [==============================] - 2s 297ms/step - loss: 8628150.0000 - mean_absolute_percentage_error: 8628150.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4141 - val_loss: 8538041.0000 - val_mean_absolute_percentage_error: 8538041.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4832
# Epoch 11/50
# 8/8 [==============================] - 2s 317ms/step - loss: 8471922.0000 - mean_absolute_percentage_error: 8471922.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4155 - val_loss: 8393618.0000 - val_mean_absolute_percentage_error: 8393618.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4835
# Epoch 12/50
# 8/8 [==============================] - 2s 297ms/step - loss: 8330964.0000 - mean_absolute_percentage_error: 8330964.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4170 - val_loss: 8248153.5000 - val_mean_absolute_percentage_error: 8248153.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4838
# Epoch 13/50
# 8/8 [==============================] - 2s 312ms/step - loss: 8192374.5000 - mean_absolute_percentage_error: 8192374.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4185 - val_loss: 8102174.5000 - val_mean_absolute_percentage_error: 8102174.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4841
# Epoch 14/50
# 8/8 [==============================] - 2s 307ms/step - loss: 8037463.0000 - mean_absolute_percentage_error: 8037463.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4198 - val_loss: 7968541.0000 - val_mean_absolute_percentage_error: 7968541.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4843
# Epoch 15/50
# 8/8 [==============================] - 2s 301ms/step - loss: 7917222.5000 - mean_absolute_percentage_error: 7917222.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4214 - val_loss: 7823574.5000 - val_mean_absolute_percentage_error: 7823574.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4846
# Epoch 16/50
# 8/8 [==============================] - 2s 323ms/step - loss: 7758768.0000 - mean_absolute_percentage_error: 7758769.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4225 - val_loss: 7695820.0000 - val_mean_absolute_percentage_error: 7695820.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4848
# Epoch 17/50
# 8/8 [==============================] - 2s 317ms/step - loss: 7642705.5000 - mean_absolute_percentage_error: 7642705.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4240 - val_loss: 7556307.0000 - val_mean_absolute_percentage_error: 7556307.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4851
# Epoch 18/50
# 8/8 [==============================] - 3s 337ms/step - loss: 7503079.0000 - mean_absolute_percentage_error: 7503079.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4253 - val_loss: 7422972.0000 - val_mean_absolute_percentage_error: 7422972.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4854
# Epoch 19/50
# 8/8 [==============================] - 2s 316ms/step - loss: 7366334.5000 - mean_absolute_percentage_error: 7366334.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4265 - val_loss: 7295731.0000 - val_mean_absolute_percentage_error: 7295731.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4856
# Epoch 20/50
# 8/8 [==============================] - 2s 319ms/step - loss: 7237817.5000 - mean_absolute_percentage_error: 7237817.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4278 - val_loss: 7169198.5000 - val_mean_absolute_percentage_error: 7169198.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4859
# Epoch 21/50
# 8/8 [==============================] - 2s 310ms/step - loss: 7115118.5000 - mean_absolute_percentage_error: 7115118.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4291 - val_loss: 7040825.0000 - val_mean_absolute_percentage_error: 7040825.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4861
# Epoch 22/50
# 8/8 [==============================] - 2s 316ms/step - loss: 6981952.0000 - mean_absolute_percentage_error: 6981952.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4303 - val_loss: 6919126.5000 - val_mean_absolute_percentage_error: 6919126.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4864
# Epoch 23/50
# 8/8 [==============================] - 2s 315ms/step - loss: 6860166.5000 - mean_absolute_percentage_error: 6860166.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4315 - val_loss: 6796631.0000 - val_mean_absolute_percentage_error: 6796631.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4866
# Epoch 24/50
# 8/8 [==============================] - 2s 317ms/step - loss: 6743326.5000 - mean_absolute_percentage_error: 6743326.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4328 - val_loss: 6671291.5000 - val_mean_absolute_percentage_error: 6671291.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4868
# Epoch 25/50
# 8/8 [==============================] - 2s 306ms/step - loss: 6615562.5000 - mean_absolute_percentage_error: 6615562.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4339 - val_loss: 6552879.5000 - val_mean_absolute_percentage_error: 6552879.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4871
# Epoch 26/50
# 8/8 [==============================] - 3s 337ms/step - loss: 6503028.5000 - mean_absolute_percentage_error: 6503028.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4352 - val_loss: 6430787.0000 - val_mean_absolute_percentage_error: 6430787.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4873
# Epoch 27/50
# 8/8 [==============================] - 2s 309ms/step - loss: 6377739.0000 - mean_absolute_percentage_error: 6377739.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4363 - val_loss: 6316003.5000 - val_mean_absolute_percentage_error: 6316003.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4875
# Epoch 28/50
# 8/8 [==============================] - 2s 310ms/step - loss: 6273679.0000 - mean_absolute_percentage_error: 6273679.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4377 - val_loss: 6194573.5000 - val_mean_absolute_percentage_error: 6194573.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4878
# Epoch 29/50
# 8/8 [==============================] - 2s 315ms/step - loss: 6150645.0000 - mean_absolute_percentage_error: 6150645.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4388 - val_loss: 6081295.0000 - val_mean_absolute_percentage_error: 6081295.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4880
# Epoch 30/50
# 8/8 [==============================] - 2s 322ms/step - loss: 6036557.5000 - mean_absolute_percentage_error: 6036557.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4399 - val_loss: 5970602.0000 - val_mean_absolute_percentage_error: 5970602.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4882
# Epoch 31/50
# 8/8 [==============================] - 2s 315ms/step - loss: 5922442.0000 - mean_absolute_percentage_error: 5922442.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4409 - val_loss: 5863835.0000 - val_mean_absolute_percentage_error: 5863835.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4884
# Epoch 32/50
# 8/8 [==============================] - 2s 308ms/step - loss: 5820427.0000 - mean_absolute_percentage_error: 5820427.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4420 - val_loss: 5753053.0000 - val_mean_absolute_percentage_error: 5753053.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4886
# Epoch 33/50
# 8/8 [==============================] - 2s 323ms/step - loss: 5707247.0000 - mean_absolute_percentage_error: 5707247.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4431 - val_loss: 5647954.5000 - val_mean_absolute_percentage_error: 5647954.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4888
# Epoch 34/50
# 8/8 [==============================] - 2s 309ms/step - loss: 5608806.0000 - mean_absolute_percentage_error: 5608806.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4442 - val_loss: 5538982.5000 - val_mean_absolute_percentage_error: 5538982.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4890
# Epoch 35/50
# 8/8 [==============================] - 2s 324ms/step - loss: 5495311.0000 - mean_absolute_percentage_error: 5495311.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4452 - val_loss: 5437781.0000 - val_mean_absolute_percentage_error: 5437781.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4892
# Epoch 36/50
# 8/8 [==============================] - 3s 433ms/step - loss: 5394794.0000 - mean_absolute_percentage_error: 5394794.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4462 - val_loss: 5335782.5000 - val_mean_absolute_percentage_error: 5335782.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4894
# Epoch 37/50
# 8/8 [==============================] - 3s 346ms/step - loss: 5290055.5000 - mean_absolute_percentage_error: 5290055.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4472 - val_loss: 5237309.0000 - val_mean_absolute_percentage_error: 5237309.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4896
# Epoch 38/50
# 8/8 [==============================] - 2s 314ms/step - loss: 5193694.5000 - mean_absolute_percentage_error: 5193694.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4482 - val_loss: 5136815.0000 - val_mean_absolute_percentage_error: 5136815.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4898
# Epoch 39/50
# 8/8 [==============================] - 2s 315ms/step - loss: 5093689.5000 - mean_absolute_percentage_error: 5093689.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4492 - val_loss: 5038311.0000 - val_mean_absolute_percentage_error: 5038311.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4900
# Epoch 40/50
# 8/8 [==============================] - 2s 304ms/step - loss: 4993603.0000 - mean_absolute_percentage_error: 4993603.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4501 - val_loss: 4943003.0000 - val_mean_absolute_percentage_error: 4943003.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4902
# Epoch 41/50
# 8/8 [==============================] - 3s 331ms/step - loss: 4897033.0000 - mean_absolute_percentage_error: 4897033.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4510 - val_loss: 4849081.0000 - val_mean_absolute_percentage_error: 4849081.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4904
# Epoch 42/50
# 8/8 [==============================] - 2s 319ms/step - loss: 4805462.5000 - mean_absolute_percentage_error: 4805462.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4520 - val_loss: 4753461.0000 - val_mean_absolute_percentage_error: 4753461.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4906
# Epoch 43/50
# 8/8 [==============================] - 2s 314ms/step - loss: 4711459.5000 - mean_absolute_percentage_error: 4711459.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4530 - val_loss: 4659293.0000 - val_mean_absolute_percentage_error: 4659293.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4908
# Epoch 44/50
# 8/8 [==============================] - 2s 321ms/step - loss: 4618451.0000 - mean_absolute_percentage_error: 4618451.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4539 - val_loss: 4566913.0000 - val_mean_absolute_percentage_error: 4566913.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4909
# Epoch 45/50
# 8/8 [==============================] - 2s 328ms/step - loss: 4524688.0000 - mean_absolute_percentage_error: 4524689.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4548 - val_loss: 4477833.5000 - val_mean_absolute_percentage_error: 4477833.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4911
# Epoch 46/50
# 8/8 [==============================] - 3s 330ms/step - loss: 4438347.0000 - mean_absolute_percentage_error: 4438347.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4557 - val_loss: 4387175.0000 - val_mean_absolute_percentage_error: 4387175.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4913
# Epoch 47/50
# 8/8 [==============================] - 2s 319ms/step - loss: 4351599.0000 - mean_absolute_percentage_error: 4351599.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4567 - val_loss: 4296479.0000 - val_mean_absolute_percentage_error: 4296479.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4915
# Epoch 48/50
# 8/8 [==============================] - 2s 323ms/step - loss: 4260999.0000 - mean_absolute_percentage_error: 4260999.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4575 - val_loss: 4209635.0000 - val_mean_absolute_percentage_error: 4209635.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4917
# Epoch 49/50
# 8/8 [==============================] - 2s 325ms/step - loss: 4171997.5000 - mean_absolute_percentage_error: 4171997.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4583 - val_loss: 4126158.5000 - val_mean_absolute_percentage_error: 4126158.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4918
# Epoch 50/50
# 8/8 [==============================] - 3s 326ms/step - loss: 4088432.7500 - mean_absolute_percentage_error: 4088432.7500 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4592 - val_loss: 4042726.7500 - val_mean_absolute_percentage_error: 4042726.7500 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4920
# 2/2 [==============================] - 1s 44ms/step - loss: 4042717.2500 - mean_absolute_percentage_error: 4042717.2500 - mean_absolute_error: 0.4008 - mean_squared_error: 0.3936
#
# [cirq.ISWAP]
# Model: "sequential_69"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_69 (PQC)                (None, 1)                 16
#
# =================================================================
# Total params: 16
# Trainable params: 16
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 5s 552ms/step - loss: 1561.5465 - mean_absolute_percentage_error: 1561.5465 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1517.4572 - val_mean_absolute_percentage_error: 1517.4572 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 2/50
# 8/8 [==============================] - 4s 505ms/step - loss: 1456.4524 - mean_absolute_percentage_error: 1456.4524 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1400.1249 - val_mean_absolute_percentage_error: 1400.1249 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 3/50
# 8/8 [==============================] - 4s 505ms/step - loss: 1356.9000 - mean_absolute_percentage_error: 1356.9000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1296.0497 - val_mean_absolute_percentage_error: 1296.0497 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 4/50
# 8/8 [==============================] - 4s 508ms/step - loss: 1261.6023 - mean_absolute_percentage_error: 1261.6023 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1213.8605 - val_mean_absolute_percentage_error: 1213.8605 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 5/50
# 8/8 [==============================] - 4s 503ms/step - loss: 1172.6727 - mean_absolute_percentage_error: 1172.6727 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1116.7992 - val_mean_absolute_percentage_error: 1116.7992 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 6/50
# 8/8 [==============================] - 4s 513ms/step - loss: 1083.6674 - mean_absolute_percentage_error: 1083.6674 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 1057.4279 - val_mean_absolute_percentage_error: 1057.4279 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 7/50
# 8/8 [==============================] - 5s 700ms/step - loss: 1012.2933 - mean_absolute_percentage_error: 1012.2933 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 979.1967 - val_mean_absolute_percentage_error: 979.1967 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 8/50
# 8/8 [==============================] - 4s 511ms/step - loss: 941.1180 - mean_absolute_percentage_error: 941.1180 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 891.4194 - val_mean_absolute_percentage_error: 891.4194 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 9/50
# 8/8 [==============================] - 4s 504ms/step - loss: 872.9684 - mean_absolute_percentage_error: 872.9684 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 833.9099 - val_mean_absolute_percentage_error: 833.9099 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 10/50
# 8/8 [==============================] - 4s 517ms/step - loss: 810.4641 - mean_absolute_percentage_error: 810.4641 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 774.0728 - val_mean_absolute_percentage_error: 774.0728 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 11/50
# 8/8 [==============================] - 4s 515ms/step - loss: 749.6730 - mean_absolute_percentage_error: 749.6730 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 712.6055 - val_mean_absolute_percentage_error: 712.6055 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 12/50
# 8/8 [==============================] - 4s 497ms/step - loss: 695.4014 - mean_absolute_percentage_error: 695.4014 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 653.0009 - val_mean_absolute_percentage_error: 653.0009 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 13/50
# 8/8 [==============================] - 4s 508ms/step - loss: 644.8295 - mean_absolute_percentage_error: 644.8294 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 623.2058 - val_mean_absolute_percentage_error: 623.2058 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 14/50
# 8/8 [==============================] - 4s 522ms/step - loss: 595.5786 - mean_absolute_percentage_error: 595.5786 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 571.2773 - val_mean_absolute_percentage_error: 571.2773 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 15/50
# 8/8 [==============================] - 4s 515ms/step - loss: 553.4198 - mean_absolute_percentage_error: 553.4198 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 517.2604 - val_mean_absolute_percentage_error: 517.2604 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 16/50
# 8/8 [==============================] - 4s 471ms/step - loss: 512.5945 - mean_absolute_percentage_error: 512.5945 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 468.6063 - val_mean_absolute_percentage_error: 468.6063 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 17/50
# 8/8 [==============================] - 4s 489ms/step - loss: 459.5793 - mean_absolute_percentage_error: 459.5793 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 459.5186 - val_mean_absolute_percentage_error: 459.5186 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 18/50
# 8/8 [==============================] - 4s 515ms/step - loss: 430.7327 - mean_absolute_percentage_error: 430.7327 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 401.7766 - val_mean_absolute_percentage_error: 401.7766 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 19/50
# 8/8 [==============================] - 4s 496ms/step - loss: 395.5615 - mean_absolute_percentage_error: 395.5615 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 386.8754 - val_mean_absolute_percentage_error: 386.8754 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 20/50
# 8/8 [==============================] - 4s 495ms/step - loss: 350.1705 - mean_absolute_percentage_error: 350.1705 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 340.3166 - val_mean_absolute_percentage_error: 340.3166 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 21/50
# 8/8 [==============================] - 4s 523ms/step - loss: 331.6298 - mean_absolute_percentage_error: 331.6298 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 297.4757 - val_mean_absolute_percentage_error: 297.4757 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 22/50
# 8/8 [==============================] - 4s 534ms/step - loss: 282.7321 - mean_absolute_percentage_error: 282.7321 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 282.5746 - val_mean_absolute_percentage_error: 282.5746 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 23/50
# 8/8 [==============================] - 4s 528ms/step - loss: 265.8766 - mean_absolute_percentage_error: 265.8766 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 235.7757 - val_mean_absolute_percentage_error: 235.7757 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 24/50
# 8/8 [==============================] - 4s 527ms/step - loss: 228.0657 - mean_absolute_percentage_error: 228.0657 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 222.9627 - val_mean_absolute_percentage_error: 222.9627 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 25/50
# 8/8 [==============================] - 4s 504ms/step - loss: 214.4440 - mean_absolute_percentage_error: 214.4440 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 178.4993 - val_mean_absolute_percentage_error: 178.4993 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 26/50
# 8/8 [==============================] - 4s 563ms/step - loss: 170.4045 - mean_absolute_percentage_error: 170.4045 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 161.2700 - val_mean_absolute_percentage_error: 161.2700 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 27/50
# 8/8 [==============================] - 5s 580ms/step - loss: 158.0791 - mean_absolute_percentage_error: 158.0791 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 146.6017 - val_mean_absolute_percentage_error: 146.6017 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 28/50
# 8/8 [==============================] - 4s 515ms/step - loss: 128.9156 - mean_absolute_percentage_error: 128.9156 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 103.5205 - val_mean_absolute_percentage_error: 103.5205 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 29/50
# 8/8 [==============================] - 4s 512ms/step - loss: 101.5457 - mean_absolute_percentage_error: 101.5457 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 103.5208 - val_mean_absolute_percentage_error: 103.5208 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 30/50
# 8/8 [==============================] - 4s 517ms/step - loss: 83.6399 - mean_absolute_percentage_error: 83.6399 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 56.9617 - val_mean_absolute_percentage_error: 56.9617 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 31/50
# 8/8 [==============================] - 4s 502ms/step - loss: 57.0311 - mean_absolute_percentage_error: 57.0311 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 65.1645 - val_mean_absolute_percentage_error: 65.1645 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 32/50
# 8/8 [==============================] - 4s 489ms/step - loss: 61.5289 - mean_absolute_percentage_error: 61.5289 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 56.0841 - val_mean_absolute_percentage_error: 56.0841 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 33/50
# 8/8 [==============================] - 4s 530ms/step - loss: 57.5582 - mean_absolute_percentage_error: 57.5582 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 50.2561 - val_mean_absolute_percentage_error: 50.2561 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 34/50
# 8/8 [==============================] - 4s 505ms/step - loss: 54.9246 - mean_absolute_percentage_error: 54.9246 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 59.0572 - val_mean_absolute_percentage_error: 59.0572 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 35/50
# 8/8 [==============================] - 4s 517ms/step - loss: 56.9030 - mean_absolute_percentage_error: 56.9030 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 55.8511 - val_mean_absolute_percentage_error: 55.8511 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 36/50
# 8/8 [==============================] - 4s 492ms/step - loss: 58.7961 - mean_absolute_percentage_error: 58.7961 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 51.6066 - val_mean_absolute_percentage_error: 51.6066 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 37/50
# 8/8 [==============================] - 5s 658ms/step - loss: 54.8545 - mean_absolute_percentage_error: 54.8545 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 50.0230 - val_mean_absolute_percentage_error: 50.0230 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 38/50
# 8/8 [==============================] - 4s 481ms/step - loss: 54.7181 - mean_absolute_percentage_error: 54.7181 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 51.6066 - val_mean_absolute_percentage_error: 51.6066 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 39/50
# 8/8 [==============================] - 4s 517ms/step - loss: 55.1283 - mean_absolute_percentage_error: 55.1283 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 55.8440 - val_mean_absolute_percentage_error: 55.8440 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 40/50
# 8/8 [==============================] - 4s 500ms/step - loss: 57.5918 - mean_absolute_percentage_error: 57.5918 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 57.1875 - val_mean_absolute_percentage_error: 57.1875 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 41/50
# 8/8 [==============================] - 4s 529ms/step - loss: 59.1916 - mean_absolute_percentage_error: 59.1916 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 57.4276 - val_mean_absolute_percentage_error: 57.4276 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# 2/2 [==============================] - 1s 128ms/step - loss: 57.4276 - mean_absolute_percentage_error: 57.4276 - mean_absolute_error: 0.5000 - mean_squared_error: 0.5000
#
# [cirq.SWAP, cirq.CNOT, cirq.CNOT]
# Model: "sequential_70"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_70 (PQC)                (None, 1)                 8
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 5s 528ms/step - loss: 32602500.0000 - mean_absolute_percentage_error: 32602500.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1781 - val_loss: 32441556.0000 - val_mean_absolute_percentage_error: 32441556.0000 - val_mean_absolute_error: 0.5228 - val_mean_squared_error: 0.4847
# Epoch 2/50
# 8/8 [==============================] - 4s 460ms/step - loss: 32320922.0000 - mean_absolute_percentage_error: 32320922.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1812 - val_loss: 32141748.0000 - val_mean_absolute_percentage_error: 32141748.0000 - val_mean_absolute_error: 0.5226 - val_mean_squared_error: 0.4847
# Epoch 3/50
# 8/8 [==============================] - 4s 474ms/step - loss: 32006508.0000 - mean_absolute_percentage_error: 32006508.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1838 - val_loss: 31861236.0000 - val_mean_absolute_percentage_error: 31861236.0000 - val_mean_absolute_error: 0.5224 - val_mean_squared_error: 0.4848
# Epoch 4/50
# 8/8 [==============================] - 4s 464ms/step - loss: 31752566.0000 - mean_absolute_percentage_error: 31752566.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1869 - val_loss: 31571878.0000 - val_mean_absolute_percentage_error: 31571878.0000 - val_mean_absolute_error: 0.5222 - val_mean_squared_error: 0.4849
# Epoch 5/50
# 8/8 [==============================] - 4s 480ms/step - loss: 31453764.0000 - mean_absolute_percentage_error: 31453764.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1895 - val_loss: 31290592.0000 - val_mean_absolute_percentage_error: 31290592.0000 - val_mean_absolute_error: 0.5219 - val_mean_squared_error: 0.4849
# Epoch 6/50
# 8/8 [==============================] - 4s 457ms/step - loss: 31171248.0000 - mean_absolute_percentage_error: 31171248.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1923 - val_loss: 31008154.0000 - val_mean_absolute_percentage_error: 31008154.0000 - val_mean_absolute_error: 0.5217 - val_mean_squared_error: 0.4850
# Epoch 7/50
# 8/8 [==============================] - 5s 624ms/step - loss: 30878876.0000 - mean_absolute_percentage_error: 30878876.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1949 - val_loss: 30730806.0000 - val_mean_absolute_percentage_error: 30730806.0000 - val_mean_absolute_error: 0.5215 - val_mean_squared_error: 0.4850
# Epoch 8/50
# 8/8 [==============================] - 4s 469ms/step - loss: 30620758.0000 - mean_absolute_percentage_error: 30620758.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.1979 - val_loss: 30439088.0000 - val_mean_absolute_percentage_error: 30439088.0000 - val_mean_absolute_error: 0.5213 - val_mean_squared_error: 0.4851
# Epoch 9/50
# 8/8 [==============================] - 4s 460ms/step - loss: 30319316.0000 - mean_absolute_percentage_error: 30319316.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2006 - val_loss: 30158832.0000 - val_mean_absolute_percentage_error: 30158832.0000 - val_mean_absolute_error: 0.5211 - val_mean_squared_error: 0.4852
# Epoch 10/50
# 8/8 [==============================] - 4s 477ms/step - loss: 30049670.0000 - mean_absolute_percentage_error: 30049670.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2035 - val_loss: 29868624.0000 - val_mean_absolute_percentage_error: 29868624.0000 - val_mean_absolute_error: 0.5208 - val_mean_squared_error: 0.4852
# Epoch 11/50
# 8/8 [==============================] - 4s 476ms/step - loss: 29740006.0000 - mean_absolute_percentage_error: 29740006.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2059 - val_loss: 29595434.0000 - val_mean_absolute_percentage_error: 29595434.0000 - val_mean_absolute_error: 0.5206 - val_mean_squared_error: 0.4853
# Epoch 12/50
# 8/8 [==============================] - 4s 498ms/step - loss: 29469088.0000 - mean_absolute_percentage_error: 29469088.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2088 - val_loss: 29309900.0000 - val_mean_absolute_percentage_error: 29309900.0000 - val_mean_absolute_error: 0.5204 - val_mean_squared_error: 0.4854
# Epoch 13/50
# 8/8 [==============================] - 2s 314ms/step - loss: 29174554.0000 - mean_absolute_percentage_error: 29174554.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2114 - val_loss: 29030038.0000 - val_mean_absolute_percentage_error: 29030038.0000 - val_mean_absolute_error: 0.5202 - val_mean_squared_error: 0.4854
# Epoch 14/50
# 8/8 [==============================] - 2s 314ms/step - loss: 28903168.0000 - mean_absolute_percentage_error: 28903168.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2143 - val_loss: 28738596.0000 - val_mean_absolute_percentage_error: 28738596.0000 - val_mean_absolute_error: 0.5200 - val_mean_squared_error: 0.4855
# Epoch 15/50
# 8/8 [==============================] - 2s 317ms/step - loss: 28628736.0000 - mean_absolute_percentage_error: 28628736.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2175 - val_loss: 28441476.0000 - val_mean_absolute_percentage_error: 28441476.0000 - val_mean_absolute_error: 0.5198 - val_mean_squared_error: 0.4856
# Epoch 16/50
# 8/8 [==============================] - 2s 316ms/step - loss: 28315082.0000 - mean_absolute_percentage_error: 28315082.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2199 - val_loss: 28165818.0000 - val_mean_absolute_percentage_error: 28165818.0000 - val_mean_absolute_error: 0.5195 - val_mean_squared_error: 0.4857
# Epoch 17/50
# 8/8 [==============================] - 2s 313ms/step - loss: 28028444.0000 - mean_absolute_percentage_error: 28028444.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2225 - val_loss: 27892506.0000 - val_mean_absolute_percentage_error: 27892506.0000 - val_mean_absolute_error: 0.5193 - val_mean_squared_error: 0.4858
# Epoch 18/50
# 8/8 [==============================] - 2s 324ms/step - loss: 27773808.0000 - mean_absolute_percentage_error: 27773808.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2256 - val_loss: 27598128.0000 - val_mean_absolute_percentage_error: 27598128.0000 - val_mean_absolute_error: 0.5191 - val_mean_squared_error: 0.4858
# Epoch 19/50
# 8/8 [==============================] - 4s 485ms/step - loss: 27464038.0000 - mean_absolute_percentage_error: 27464038.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2281 - val_loss: 27324204.0000 - val_mean_absolute_percentage_error: 27324204.0000 - val_mean_absolute_error: 0.5189 - val_mean_squared_error: 0.4859
# Epoch 20/50
# 8/8 [==============================] - 2s 316ms/step - loss: 27200528.0000 - mean_absolute_percentage_error: 27200528.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2310 - val_loss: 27038406.0000 - val_mean_absolute_percentage_error: 27038406.0000 - val_mean_absolute_error: 0.5187 - val_mean_squared_error: 0.4860
# Epoch 21/50
# 8/8 [==============================] - 2s 315ms/step - loss: 26927200.0000 - mean_absolute_percentage_error: 26927200.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2340 - val_loss: 26747792.0000 - val_mean_absolute_percentage_error: 26747792.0000 - val_mean_absolute_error: 0.5185 - val_mean_squared_error: 0.4861
# Epoch 22/50
# 8/8 [==============================] - 2s 317ms/step - loss: 26632940.0000 - mean_absolute_percentage_error: 26632940.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2367 - val_loss: 26467684.0000 - val_mean_absolute_percentage_error: 26467684.0000 - val_mean_absolute_error: 0.5183 - val_mean_squared_error: 0.4862
# Epoch 23/50
# 8/8 [==============================] - 2s 316ms/step - loss: 26341988.0000 - mean_absolute_percentage_error: 26341988.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2392 - val_loss: 26195786.0000 - val_mean_absolute_percentage_error: 26195786.0000 - val_mean_absolute_error: 0.5181 - val_mean_squared_error: 0.4862
# Epoch 24/50
# 8/8 [==============================] - 2s 315ms/step - loss: 26080718.0000 - mean_absolute_percentage_error: 26080718.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2421 - val_loss: 25909610.0000 - val_mean_absolute_percentage_error: 25909610.0000 - val_mean_absolute_error: 0.5178 - val_mean_squared_error: 0.4863
# Epoch 25/50
# 8/8 [==============================] - 2s 316ms/step - loss: 25793468.0000 - mean_absolute_percentage_error: 25793468.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2449 - val_loss: 25629670.0000 - val_mean_absolute_percentage_error: 25629670.0000 - val_mean_absolute_error: 0.5176 - val_mean_squared_error: 0.4864
# Epoch 26/50
# 8/8 [==============================] - 2s 314ms/step - loss: 25507550.0000 - mean_absolute_percentage_error: 25507550.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2474 - val_loss: 25356060.0000 - val_mean_absolute_percentage_error: 25356060.0000 - val_mean_absolute_error: 0.5174 - val_mean_squared_error: 0.4865
# Epoch 27/50
# 8/8 [==============================] - 2s 314ms/step - loss: 25217314.0000 - mean_absolute_percentage_error: 25217314.0000 - mean_absolute_error: 2.4999 - mean_squared_error: 12.2498 - val_loss: 25094508.0000 - val_mean_absolute_percentage_error: 25094508.0000 - val_mean_absolute_error: 0.5172 - val_mean_squared_error: 0.4866
# Epoch 28/50
# 8/8 [==============================] - 2s 319ms/step - loss: 24962086.0000 - mean_absolute_percentage_error: 24962088.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2527 - val_loss: 24812746.0000 - val_mean_absolute_percentage_error: 24812746.0000 - val_mean_absolute_error: 0.5170 - val_mean_squared_error: 0.4867
# Epoch 29/50
# 8/8 [==============================] - 2s 317ms/step - loss: 24681964.0000 - mean_absolute_percentage_error: 24681964.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2555 - val_loss: 24533516.0000 - val_mean_absolute_percentage_error: 24533516.0000 - val_mean_absolute_error: 0.5168 - val_mean_squared_error: 0.4868
# Epoch 30/50
# 8/8 [==============================] - 2s 314ms/step - loss: 24400782.0000 - mean_absolute_percentage_error: 24400782.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2581 - val_loss: 24257980.0000 - val_mean_absolute_percentage_error: 24257980.0000 - val_mean_absolute_error: 0.5166 - val_mean_squared_error: 0.4869
# Epoch 31/50
# 8/8 [==============================] - 2s 317ms/step - loss: 24126260.0000 - mean_absolute_percentage_error: 24126260.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2608 - val_loss: 23981514.0000 - val_mean_absolute_percentage_error: 23981514.0000 - val_mean_absolute_error: 0.5164 - val_mean_squared_error: 0.4870
# Epoch 32/50
# 8/8 [==============================] - 2s 319ms/step - loss: 23856504.0000 - mean_absolute_percentage_error: 23856504.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2636 - val_loss: 23701156.0000 - val_mean_absolute_percentage_error: 23701156.0000 - val_mean_absolute_error: 0.5162 - val_mean_squared_error: 0.4871
# Epoch 33/50
# 8/8 [==============================] - 2s 316ms/step - loss: 23575852.0000 - mean_absolute_percentage_error: 23575852.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2664 - val_loss: 23425188.0000 - val_mean_absolute_percentage_error: 23425188.0000 - val_mean_absolute_error: 0.5160 - val_mean_squared_error: 0.4872
# Epoch 34/50
# 8/8 [==============================] - 2s 315ms/step - loss: 23308192.0000 - mean_absolute_percentage_error: 23308192.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.2692 - val_loss: 23144556.0000 - val_mean_absolute_percentage_error: 23144556.0000 - val_mean_absolute_error: 0.5158 - val_mean_squared_error: 0.4873
# Epoch 35/50
# ...
# Epoch 19/50
# 8/8 [==============================] - 3s 346ms/step - loss: 8036667.0000 - mean_absolute_percentage_error: 8036667.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4201 - val_loss: 7587265.0000 - val_mean_absolute_percentage_error: 7587265.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4851
# Epoch 20/50
# 8/8 [==============================] - 3s 352ms/step - loss: 7254645.0000 - mean_absolute_percentage_error: 7254645.0000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4280 - val_loss: 6800315.0000 - val_mean_absolute_percentage_error: 6800315.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4866
# Epoch 21/50
# 8/8 [==============================] - 3s 349ms/step - loss: 6444220.5000 - mean_absolute_percentage_error: 6444220.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4353 - val_loss: 6035118.0000 - val_mean_absolute_percentage_error: 6035118.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4881
# Epoch 22/50
# 8/8 [==============================] - 4s 526ms/step - loss: 5662481.0000 - mean_absolute_percentage_error: 5662480.5000 - mean_absolute_error: 2.4999 - mean_squared_error: 12.4427 - val_loss: 5271886.5000 - val_mean_absolute_percentage_error: 5271886.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4896
# Epoch 23/50
# 8/8 [==============================] - 3s 353ms/step - loss: 4908847.5000 - mean_absolute_percentage_error: 4908847.5000 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4505 - val_loss: 4492298.0000 - val_mean_absolute_percentage_error: 4492298.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4911
# Epoch 24/50
# 8/8 [==============================] - 3s 352ms/step - loss: 4092792.0000 - mean_absolute_percentage_error: 4092792.0000 - mean_absolute_error: 2.4998 - mean_squared_error: 12.4575 - val_loss: 3749594.0000 - val_mean_absolute_percentage_error: 3749594.0000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4926
# Epoch 25/50
# 8/8 [==============================] - 3s 351ms/step - loss: 3413872.0000 - mean_absolute_percentage_error: 3413872.0000 - mean_absolute_error: 2.5001 - mean_squared_error: 12.4664 - val_loss: 2939061.5000 - val_mean_absolute_percentage_error: 2939061.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4942
# Epoch 26/50
# 8/8 [==============================] - 3s 350ms/step - loss: 2629305.5000 - mean_absolute_percentage_error: 2629305.5000 - mean_absolute_error: 2.5001 - mean_squared_error: 12.4745 - val_loss: 2146235.7500 - val_mean_absolute_percentage_error: 2146235.7500 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4957
# Epoch 27/50
# 8/8 [==============================] - 3s 352ms/step - loss: 1838034.2500 - mean_absolute_percentage_error: 1838034.2500 - mean_absolute_error: 2.5001 - mean_squared_error: 12.4821 - val_loss: 1375118.5000 - val_mean_absolute_percentage_error: 1375118.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4973
# Epoch 28/50
# 8/8 [==============================] - 3s 346ms/step - loss: 1041051.1875 - mean_absolute_percentage_error: 1041051.1875 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4893 - val_loss: 629213.5000 - val_mean_absolute_percentage_error: 629213.5000 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4987
# Epoch 29/50
# 8/8 [==============================] - 3s 352ms/step - loss: 302554.0312 - mean_absolute_percentage_error: 302554.0312 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4969 - val_loss: 115213.4375 - val_mean_absolute_percentage_error: 115213.4375 - val_mean_absolute_error: 0.5002 - val_mean_squared_error: 0.5002
# Epoch 30/50
# 8/8 [==============================] - 3s 350ms/step - loss: 293649.1562 - mean_absolute_percentage_error: 293649.1562 - mean_absolute_error: 2.5005 - mean_squared_error: 12.5024 - val_loss: 298679.9062 - val_mean_absolute_percentage_error: 298679.9062 - val_mean_absolute_error: 0.5006 - val_mean_squared_error: 0.5006
# Epoch 31/50
# 8/8 [==============================] - 3s 353ms/step - loss: 150168.5938 - mean_absolute_percentage_error: 150168.5938 - mean_absolute_error: 2.5003 - mean_squared_error: 12.5017 - val_loss: 71879.6328 - val_mean_absolute_percentage_error: 71879.6328 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 32/50
# 8/8 [==============================] - 3s 349ms/step - loss: 128865.9219 - mean_absolute_percentage_error: 128865.9219 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4987 - val_loss: 90041.3203 - val_mean_absolute_percentage_error: 90041.3203 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4998
# Epoch 33/50
# 8/8 [==============================] - 3s 348ms/step - loss: 77553.9766 - mean_absolute_percentage_error: 77553.9766 - mean_absolute_error: 2.5001 - mean_squared_error: 12.5002 - val_loss: 80575.2266 - val_mean_absolute_percentage_error: 80575.2266 - val_mean_absolute_error: 0.5002 - val_mean_squared_error: 0.5002
# Epoch 34/50
# 8/8 [==============================] - 3s 347ms/step - loss: 44299.4531 - mean_absolute_percentage_error: 44299.4531 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 9777.0693 - val_mean_absolute_percentage_error: 9777.0693 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 35/50
# 8/8 [==============================] - 3s 347ms/step - loss: 28002.3379 - mean_absolute_percentage_error: 28002.3379 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5001 - val_loss: 37892.3438 - val_mean_absolute_percentage_error: 37892.3438 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 36/50
# 8/8 [==============================] - 3s 345ms/step - loss: 23871.0586 - mean_absolute_percentage_error: 23871.0586 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4999 - val_loss: 18602.9004 - val_mean_absolute_percentage_error: 18602.9004 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 37/50
# 8/8 [==============================] - 3s 345ms/step - loss: 11021.7070 - mean_absolute_percentage_error: 11021.7070 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4999 - val_loss: 832.7220 - val_mean_absolute_percentage_error: 832.7220 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 38/50
# 8/8 [==============================] - 3s 352ms/step - loss: 4286.3833 - mean_absolute_percentage_error: 4286.3833 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 8590.1445 - val_mean_absolute_percentage_error: 8590.1445 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 39/50
# 8/8 [==============================] - 3s 350ms/step - loss: 6919.9990 - mean_absolute_percentage_error: 6919.9990 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 6248.4521 - val_mean_absolute_percentage_error: 6248.4521 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 40/50
# 8/8 [==============================] - 3s 350ms/step - loss: 6853.8999 - mean_absolute_percentage_error: 6853.8999 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 20761.4902 - val_mean_absolute_percentage_error: 20761.4902 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 41/50
# 8/8 [==============================] - 3s 347ms/step - loss: 34243.7812 - mean_absolute_percentage_error: 34243.7812 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4998 - val_loss: 26163.5840 - val_mean_absolute_percentage_error: 26163.5840 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# 2/2 [==============================] - 0s 63ms/step - loss: 26153.5801 - mean_absolute_percentage_error: 26153.5801 - mean_absolute_error: 0.4000 - mean_squared_error: 0.4000
#
# [cirq.YY, cirq.XX, cirq.CNOT]
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  pqc_75 (PQC)                (None, 1)                 48
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 8/8 [==============================] - 7s 773ms/step - loss: 139803.7031 - mean_absolute_percentage_error: 139803.7031 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4986 - val_loss: 130939.1875 - val_mean_absolute_percentage_error: 130939.1875 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4997
# Epoch 2/50
# 8/8 [==============================] - 6s 748ms/step - loss: 123327.6875 - mean_absolute_percentage_error: 123327.6875 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4988 - val_loss: 113438.4141 - val_mean_absolute_percentage_error: 113438.4141 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4998
# Epoch 3/50
# 8/8 [==============================] - 6s 750ms/step - loss: 106451.6406 - mean_absolute_percentage_error: 106451.6406 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4989 - val_loss: 97310.9922 - val_mean_absolute_percentage_error: 97310.9922 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4998
# Epoch 4/50
# 8/8 [==============================] - 6s 746ms/step - loss: 90156.6406 - mean_absolute_percentage_error: 90156.6406 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4991 - val_loss: 82593.1719 - val_mean_absolute_percentage_error: 82593.1719 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4998
# Epoch 5/50
# 8/8 [==============================] - 6s 745ms/step - loss: 76014.1797 - mean_absolute_percentage_error: 76014.1797 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4992 - val_loss: 68661.3828 - val_mean_absolute_percentage_error: 68661.3828 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 6/50
# 8/8 [==============================] - 6s 754ms/step - loss: 62402.1758 - mean_absolute_percentage_error: 62402.1758 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4994 - val_loss: 55771.6562 - val_mean_absolute_percentage_error: 55771.6562 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 7/50
# 8/8 [==============================] - 6s 746ms/step - loss: 50718.4375 - mean_absolute_percentage_error: 50718.4375 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4995 - val_loss: 43307.0938 - val_mean_absolute_percentage_error: 43307.0938 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 8/50
# 8/8 [==============================] - 6s 775ms/step - loss: 38072.3672 - mean_absolute_percentage_error: 38072.3633 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4996 - val_loss: 32273.0312 - val_mean_absolute_percentage_error: 32273.0312 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.4999
# Epoch 9/50
# 8/8 [==============================] - 6s 750ms/step - loss: 27285.8320 - mean_absolute_percentage_error: 27285.8320 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4997 - val_loss: 21600.3672 - val_mean_absolute_percentage_error: 21600.3672 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 10/50
# 8/8 [==============================] - 6s 756ms/step - loss: 16655.3242 - mean_absolute_percentage_error: 16655.3242 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4998 - val_loss: 11445.0820 - val_mean_absolute_percentage_error: 11445.0820 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 11/50
# 8/8 [==============================] - 6s 750ms/step - loss: 7006.2812 - mean_absolute_percentage_error: 7006.2812 - mean_absolute_error: 2.5000 - mean_squared_error: 12.4999 - val_loss: 1281.8145 - val_mean_absolute_percentage_error: 1281.8145 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 12/50
# 8/8 [==============================] - 6s 751ms/step - loss: 1946.4006 - mean_absolute_percentage_error: 1946.4006 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 3162.2622 - val_mean_absolute_percentage_error: 3162.2622 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 13/50
# 8/8 [==============================] - 7s 946ms/step - loss: 2074.9219 - mean_absolute_percentage_error: 2074.9219 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 342.7008 - val_mean_absolute_percentage_error: 342.7008 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 14/50
# 8/8 [==============================] - 6s 752ms/step - loss: 1001.1799 - mean_absolute_percentage_error: 1001.1799 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 326.1100 - val_mean_absolute_percentage_error: 326.1100 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 15/50
# 8/8 [==============================] - 6s 762ms/step - loss: 571.7936 - mean_absolute_percentage_error: 571.7936 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 396.9169 - val_mean_absolute_percentage_error: 396.9169 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 16/50
# 8/8 [==============================] - 6s 753ms/step - loss: 467.3114 - mean_absolute_percentage_error: 467.3114 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 569.4846 - val_mean_absolute_percentage_error: 569.4846 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 17/50
# 8/8 [==============================] - 6s 746ms/step - loss: 540.2613 - mean_absolute_percentage_error: 540.2613 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 753.0483 - val_mean_absolute_percentage_error: 753.0483 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 18/50
# 8/8 [==============================] - 6s 748ms/step - loss: 558.7428 - mean_absolute_percentage_error: 558.7428 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 439.1464 - val_mean_absolute_percentage_error: 439.1464 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 19/50
# 8/8 [==============================] - 6s 749ms/step - loss: 426.7313 - mean_absolute_percentage_error: 426.7313 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 182.6439 - val_mean_absolute_percentage_error: 182.6439 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 20/50
# 8/8 [==============================] - 6s 756ms/step - loss: 289.0224 - mean_absolute_percentage_error: 289.0224 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 60.8617 - val_mean_absolute_percentage_error: 60.8617 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 21/50
# 8/8 [==============================] - 6s 755ms/step - loss: 295.4828 - mean_absolute_percentage_error: 295.4828 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 699.4762 - val_mean_absolute_percentage_error: 699.4762 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 22/50
# 8/8 [==============================] - 6s 749ms/step - loss: 526.8257 - mean_absolute_percentage_error: 526.8257 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 378.2365 - val_mean_absolute_percentage_error: 378.2365 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# Epoch 23/50
# 8/8 [==============================] - 6s 754ms/step - loss: 331.3655 - mean_absolute_percentage_error: 331.3655 - mean_absolute_error: 2.5000 - mean_squared_error: 12.5000 - val_loss: 461.9241 - val_mean_absolute_percentage_error: 461.9241 - val_mean_absolute_error: 0.5000 - val_mean_squared_error: 0.5000
# 2/2 [==============================] - 1s 168ms/step - loss: 461.9242 - mean_absolute_percentage_error: 461.9242 - mean_absolute_error: 0.5000 - mean_squared_error: 0.5000

# %% [markdown]
# ##Circuit #1 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 1))

# %% [markdown]
# ##Circuit #2 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 2))

# %% [markdown]
# ##Circuit #3 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 3))

# %% [markdown]
# ##Circuit #4 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 4))

# %% [markdown]
# ##Circuit #5 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 5))

# %% [markdown]
# ##Circuit #6 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 6))

# %% [markdown]
# ##Circuit #7 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 7))

# %% [markdown]
# ##Circuit #8 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 8))

# %% [markdown]
# ##Circuit #9 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 9))

# %% [markdown]
# ##Circuit #10 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 10))

# %% [markdown]
# ##Circuit #11 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 11))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-59945d57f7b2> in <module>()
# ----> 1 SVGCircuit(experiment_reveal(experiment_log, 11))
#
# <ipython-input-72-eabc055b8a98> in experiment_reveal(log, run)
#       3
#       4   fig, (ax1, ax2) = pyplot.subplots(2)
# ----> 5   pyplot.title('MSE Loss and Accuracy of %s gated Parametrized Quantum Circuit' % (log[run]['gates']), fontdict = {'fontsize' :16})
#       6
#       7   ax1.plot(log[run]['history'].history['loss'])
#
# KeyError: 11

# %% [markdown]
# ##Circuit #12 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 12))

# %% [markdown]
# ##Circuit #13 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 13))

# %% [markdown]
# ##Circuit #14 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 14))

# %% [markdown]
# ##Circuit #15 - design and results

# %%
SVGCircuit(experiment_reveal(experiment_log, 14))

# %%
experiment_log

# %%
#df = pandas.DataFrame.from_dict(experiment_log)
# print(df['results'])
#pandas.DataFrame(data=zip(df['results']),columns=['list1','list2','list3'])
#pandas.DataFrame(data=zip(df['results']))
#type(df['results'])
# ff = df['results']
#pandas.DataFrame(ff)
# df1 = df.explode(['gates', 'results'])

# df.explode(['gates', 'results'])

# print(df1)
#df1.explode('B')

#df.set_index(['gates'], drop = True).unstack('results')

g = []
for key, value in experiment_log.items():
  print('run #%d' % key)

  for sub_key, sub_value in value.items():
      print(sub_key)
      print(type(sub_value))

      try:
        for sub_sub_value in sub_value:
          print(sub_sub_value)
      except:
        pass
